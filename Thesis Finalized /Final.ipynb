# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/Users/muballighhossain/Desktop/Thesis/P3/windows10_dataset.csv')
print(df.shape)
df.head()
# Out:
# (35975, 127)
#            ts  Processor_DPC_Rate Processor_pct_ Idle_Time  \
# 0  1554206309                   4              29.90817156
# 1  1554206319                   9              31.75168186
# 2  1554206329                   5              29.49516707
# 3  1554206339                  12              18.22437505
# 4  1554206349                  12              14.86118688
#
#   Processor_pct_ C3_Time Processor_pct_ Interrupt_Time Processor_pct_ C2_Time  \
# 0                      0                   0.078240397                      0
# 1                      0                   0.312520973                      0
# 2                      0                    1.16822183                      0
# 3                      0                   1.097191902                      0
# 4                      0                   1.562431019                      0
#
#   Processor_pct_ User_Time Processor_pct_ C1_Time  \
# 0              61.02750947            29.90817156
# 1              59.14459419            31.75168186
# 2              46.02794011            29.49516707
# 3              47.80621859            18.22437505
# 4               41.8731513            14.86118688
#
#   Processor_pct_ Processor_Time Processor_C1_ransitions_sec  ...  \
# 0                    66.2001486                 480.0949912  ...
# 1                   66.24773489                 427.0412837  ...
# 2                   66.90038148                 1159.426821  ...
# 3                   79.54520811                  736.622011  ...
# 4                   82.73513724                 896.1085985  ...
#
#   LogicalDisk(_Total) Avg  Disk Write Queue Length  \
# 0                                      0.134876119
# 1                                      0.157564294
# 2                                      0.401773775
# 3                                      0.259062331
# 4                                      0.103836186
#
#   LogicalDisk(_Total) Avg  Disk Queue Length  \
# 0                                0.163098103
# 1                                0.189279353
# 2                                0.782471877
# 3                                0.768934004
# 4                                1.081729712
#
#   LogicalDisk(_Total) pct_ Disk Read Time  \
# 0                             2.822198461
# 1                              3.17150584
# 2                             38.06981014
# 3                             50.98716725
# 4                              97.7893526
#
#   LogicalDisk(_Total) Disk Write Bytes sec  \
# 0                              1924988.236
# 1                              1497232.743
# 2                              1854228.536
# 3                              15912390.29
# 4                               23609299.7
#
#   LogicalDisk(_Total) Disk Transfers sec  \
# 0                            402.5827836
# 1                            355.1343322
# 2                            760.4317685
# 3                            699.4999538
# 4                            1184.550425
#
#   LogicalDisk(_Total) Avg  Disk Bytes Transfer  \
# 0                                  9100.481592
# 1                                  11153.55449
# 2                                  26994.26595
# 3                                   53141.6638
# 4                                  40988.68444
#
#    LogicalDisk(_Total) pct_ Disk Write Time  \
# 0                               13.48761188
# 1                               15.75642941
# 2                               40.17737752
# 3                               25.90623311
# 4                               10.38361856
#
#   LogicalDisk(_Total) Avg  Disk sec Transfer  label    type
# 0                                0.000405118      0  normal
# 1                                0.000532995      0  normal
# 2                                0.001028323      0  normal
# 3                                0.001099429      0  normal
# 4                                0.000912738      0  normal
#
# [5 rows x 127 columns]

# %%
df.drop(['type','ts'], inplace = True, axis = 1)

# %%
# 'Memory Pool Paged Resident Bytes', 'Memory System Driver Total Bytes', 'Memory Standby Cache Core Bytes', 'Memory Long-Term Average Standby Cache Lifetime (s)', 'Memory Pool Nonpaged Bytes', 'Memory Pool Paged Bytes',

# %%
# df.columns.values.tolist()

# %%
df = df.astype(str)

# %%
df = df[~df.applymap(lambda x: x.strip()).eq('').any(axis=1)]

# %%
# df = df[~df[['Process_IO Read_Operations_sec']].str.strip().eq('')]

# %%
print(df['Process_IO Read_Operations_sec'].str.strip().eq('').value_counts())
# Out:
# False    35214
# Name: Process_IO Read_Operations_sec, dtype: int64

# %%
# columns_with_spaces = df.columns[df.apply(lambda x: x.str.isspace().any())]
# print(columns_with_spaces)

# %%
# columns_with_spaces = windows.columns[windows.apply(lambda x: x.str.isspace().any())]
# print(columns_with_spaces)

# %%
x = df.drop('label', axis=1)
y = df['label']

from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()

rfc.fit(x,y)
fi_col = []
fi = []

for i,column in enumerate(df.drop('label', axis = 1)):
    print('The feature importance for {} is : {}'.format(column, rfc.feature_importances_[i]))
    
    fi_col.append(column)
    fi.append(rfc.feature_importances_[i])

fi_df = zip(fi_col, fi)
fi_df = pd.DataFrame(fi_df, columns = ['Feature','Feature Importance'])

# Ordering the data
fi_df = fi_df.sort_values('Feature Importance', ascending = False).reset_index()

# Creating columns to keep
columns_to_keep = fi_df['Feature']
# Out:
# The feature importance for Processor_DPC_Rate is : 0.00027646013535055587
# The feature importance for Processor_pct_ Idle_Time is : 0.003935154485380421
# The feature importance for Processor_pct_ C3_Time is : 0.0
# The feature importance for Processor_pct_ Interrupt_Time is : 0.009833173688013112
# The feature importance for Processor_pct_ C2_Time is : 0.0
# The feature importance for Processor_pct_ User_Time is : 0.005583027463010276
# The feature importance for Processor_pct_ C1_Time is : 0.0037896843268685415
# The feature importance for Processor_pct_ Processor_Time is : 0.0032250621680269295
# The feature importance for Processor_C1_ransitions_sec is : 0.0014087283632999406
# The feature importance for Processor_pct_ DPC_Time is : 0.0006313550545640694
# The feature importance for Processor_C2_ransitions_sec is : 0.0
# The feature importance for Processor_pct_ Privileged_Time is : 0.0053768516051130675
# The feature importance for Processor_C3_ransitions_sec is : 0.0
# The feature importance for Processor_DPCs_Queued_sec is : 0.0017312493384179129
# The feature importance for Processor_Interrupts_sec is : 0.0010417803968980313
# The feature importance for Process_Pool_Paged Bytes is : 0.07079774233415168
# The feature importance for Process_IO Read_Operations_sec is : 0.022391837300565067
# The feature importance for Process_Working_Set_ Private is : 0.005513880549111752
# The feature importance for Process_Working_Set_Peak is : 0.008000052119631637
# The feature importance for Process_IO_Write Operations_sec is : 0.03057326464718723
# The feature importance for Process_Page_File Bytes is : 0.007191636637305509
# The feature importance for Process_pct_ User_Time is : 0.011394481185166363
# The feature importance for Process_Virtual_Bytes Peak is : 0.03399716231989833
# The feature importance for Process_Page_File Bytes Peak is : 0.008324355615571566
# The feature importance for Process_IO_Other_Bytes_sec is : 0.0012130762142587668
# The feature importance for Process_Private_Bytes is : 0.005832006767537996
# The feature importance for Process_IO_Write_Bytes_sec is : 0.006257817622180708
# The feature importance for Process_Elapsed_Time is : 0.0
# The feature importance for Process_Virtual_Bytes is : 0.050382816898297454
# The feature importance for Process_pct_ Processor_Time is : 0.0032346867592412264
# The feature importance for Process_Creating Process ID is : 0.0
# The feature importance for Process_Pool Nonpaged Bytes is : 0.016087261926243428
# The feature importance for Process_Working Set is : 0.020960759003485235
# The feature importance for Process_Page Faults_sec is : 0.0028707654277795886
# The feature importance for Process_ID Process is : 0.0
# The feature importance for Process_IO Other Operations_sec is : 0.004872902250969005
# The feature importance for Process_IO Data Operations_sec is : 0.021169935992607056
# The feature importance for Process_Thread Count is : 0.030798170964685782
# The feature importance for Process_pct_ Privileged_Time is : 0.006164193908013672
# The feature importance for Process_IO Data Bytes_sec is : 0.0024805882627628017
# The feature importance for Process_IO Read Bytes_sec is : 0.030362907264742778
# The feature importance for Process_Priority Base is : 0.0
# The feature importance for Process_Handle Count is : 0.03863310359654545
# The feature importance for Network_I(Intel R _82574L_GNC)TCP_APS is : 0.03456278331258866
# The feature importance for Network_I(Intel R _82574L_GNC) Packets Received Unknown is : 0.0
# The feature importance for Network_I(Intel R _82574L_GNC) Bytes Received sec is : 0.006628677250046473
# The feature importance for Network_I(Intel R _82574L_GNC) Bytes Sent sec is : 0.007304610744267458
# The feature importance for Network_I(Intel R _82574L_GNC) Packets Outbound Errors is : 0.0
# The feature importance for Network_I(Intel R _82574L_GNC) Packets Received Discarded is : 0.0
# The feature importance for Network_I(Intel R _82574L_GNC) Bytes Total sec is : 0.006613708967188801
# The feature importance for Network_I(Intel R _82574L_GNC) Packets Outbound Discarded is : 0.0
# The feature importance for Network_I(Intel R _82574L_GNC) TCP RSC Exceptions sec is : 0.0
# The feature importance for Network_I(Intel R _82574L_GNC) Packets Sent Unicast sec is : 0.004304347875451045
# The feature importance for Network_I(Intel R _82574L_GNC) Output Queue Length is : 0.0
# The feature importance for Network_I(Intel R _82574L_GNC) Packets Received sec is : 0.004285193037865043
# The feature importance for Network_I(Intel R _82574L_GNC) Current Bandwidth is : 0.0
# The feature importance for Network_I(Intel R _82574L_GNC) Packets sec is : 0.004906138197845815
# The feature importance for Network_I(Intel R _82574L_GNC) TCP Active RSC Connections is : 0.007135311032099695
# The feature importance for Network_I(Intel R _82574L_GNC) Packets Sent sec is : 0.006767285744652182
# The feature importance for Network_I(Intel R _82574L_GNC) Packets Received Unicast sec is : 0.006162935624086125
# The feature importance for Network_I(Intel R _82574L_GNC) Packets Sent Non-Unicast sec is : 0.0
# The feature importance for Network_I(Intel R _82574L_GNC) Packets Received Non-Unicast sec is : 0.0
# The feature importance for Network_I(Intel R _82574L_GNC) TCP RSC Coalesced Packets sec is : 0.0
# The feature importance for Network_I(Intel R _82574L_GNC) Offloaded Connections is : 0.0
# The feature importance for Network_I(Intel R _82574L_GNC) Packets Received Errors is : 0.0
# The feature importance for Memory Pool Paged Bytes is : 0.018520016186149537
# The feature importance for Memory Free & Zero Page List Bytes is : 0.0038206960293705955
# The feature importance for Memory Cache Bytes Peak is : 0.019300532957622477
# The feature importance for Memory System Code Resident Bytes is : 8.456198994727932e-06
# The feature importance for Memory Available Bytes is : 0.001635960678556557
# The feature importance for Memory Commit Limit is : 0.007482560755951074
# The feature importance for Memory Transition Pages RePurposed sec is : 7.557615227254025e-05
# The feature importance for Memory Pages Output sec is : 3.1708816735858634e-05
# The feature importance for Memory Page Reads sec is : 0.000478153647139619
# The feature importance for Memory Demand Zero Faults sec is : 0.0038844811987884995
# The feature importance for Memory Available KBytes is : 0.002683111907047207
# The feature importance for Memory Pages sec is : 0.0004362933004721834
# The feature importance for Memory Cache Bytes is : 0.013423374187913388
# The feature importance for Memory Pool Nonpaged Bytes is : 0.036752547809755454
# The feature importance for Memory Page Faults sec is : 0.002949245209129577
# The feature importance for Memory Transition Faults sec is : 0.0008777218521336639
# The feature importance for Memory System Cache Resident Bytes is : 0.018593598132512348
# The feature importance for Memory Long-Term Average Standby Cache Lifetime (s) is : 0.019822532225255422
# The feature importance for Memory Standby Cache Reserve Bytes is : 0.005226683663000537
# The feature importance for Memory Page Writes sec is : 1.5328401778488747e-05
# The feature importance for Memory System Code Total Bytes is : 3.962979163694343e-06
# The feature importance for Memory Standby Cache Core Bytes is : 0.040057611372746896
# The feature importance for Memory System Driver Resident Bytes is : 0.012976929411145999
# The feature importance for Memory Standby Cache Normal Priority Bytes is : 0.011639034822487916
# The feature importance for Memory Pool Paged Allocs is : 2.387655132208719e-05
# The feature importance for Memory Pool Nonpaged Allocs is : 0.0
# The feature importance for Memory pct_ Committed Bytes In Use is : 0.014323530584714512
# The feature importance for Memory Free System Page Table Entries is : 0.03380376841211856
# The feature importance for Memory Available MBytes is : 0.0027919215811799667
# The feature importance for Memory Modified Page List Bytes is : 0.0018065954878189138
# The feature importance for Memory Cache Faults sec is : 0.0008657393286527977
# The feature importance for Memory Committed Bytes is : 0.011271817053776717
# The feature importance for Memory System Driver Total Bytes is : 0.016604337273078917
# The feature importance for Memory Pages Input sec is : 0.0003901779640097424
# The feature importance for Memory Pool Paged Resident Bytes is : 0.024252278046361868
# The feature importance for Memory Write Copies sec is : 0.0008466860395971012
# The feature importance for LogicalDisk(_Total) Avg  Disk Bytes Write is : 0.0008023864417318153
# The feature importance for LogicalDisk(_Total) pct_ Idle Time is : 0.001041415014880515
# The feature importance for LogicalDisk(_Total) Disk Reads sec is : 0.0003885833603510691
# The feature importance for LogicalDisk(_Total) pct_ Free Space is : 0.044526007817761865
# The feature importance for LogicalDisk(_Total) Disk Read Bytes sec is : 0.000294692286571723
# The feature importance for LogicalDisk(_Total) Avg  Disk sec Read is : 0.00040305001526025125
# The feature importance for LogicalDisk(_Total) Disk Writes sec is : 0.0008756476693812874
# The feature importance for LogicalDisk(_Total) Current Disk Queue Length is : 6.050016015496076e-05
# The feature importance for LogicalDisk(_Total) Split IO Sec is : 0.00046059143191327424
# The feature importance for LogicalDisk(_Total) Free Megabytes is : 0.0442513349459304
# The feature importance for LogicalDisk(_Total) Avg  Disk sec Write is : 0.0009844638909763956
# The feature importance for LogicalDisk(_Total) Disk Bytes sec is : 0.0009919795386256298
# The feature importance for LogicalDisk(_Total) Avg  Disk Read Queue Length is : 0.0003027443842516092
# The feature importance for LogicalDisk(_Total) pct_ Disk Time is : 0.0011810279780424511
# The feature importance for LogicalDisk(_Total) Avg  Disk Bytes Read is : 0.00027530909480053364
# The feature importance for LogicalDisk(_Total) Avg  Disk Write Queue Length is : 0.0007684157349800914
# The feature importance for LogicalDisk(_Total) Avg  Disk Queue Length is : 0.000930372729383066
# The feature importance for LogicalDisk(_Total) pct_ Disk Read Time is : 0.0020325272037189563
# The feature importance for LogicalDisk(_Total) Disk Write Bytes sec is : 0.002129050113624383
# The feature importance for LogicalDisk(_Total) Disk Transfers sec is : 0.0011002444488601975
# The feature importance for LogicalDisk(_Total) Avg  Disk Bytes Transfer is : 0.0007472913466561995
# The feature importance for LogicalDisk(_Total) pct_ Disk Write Time is : 0.0017542499964326827
# The feature importance for LogicalDisk(_Total) Avg  Disk sec Transfer is : 0.0010123437979811121

# %%
pd.set_option('display.max_rows', 124)
fi_df.head(124)
# Out:
#      index                                            Feature  \
# 0       15                           Process_Pool_Paged Bytes
# 1       28                              Process_Virtual_Bytes
# 2      104                LogicalDisk(_Total) pct_ Free Space
# 3      110                 LogicalDisk(_Total) Free Megabytes
# 4       86                    Memory Standby Cache Core Bytes
# 5       42                               Process_Handle Count
# 6       78                         Memory Pool Nonpaged Bytes
# 7       43              Network_I(Intel R _82574L_GNC)TCP_APS
# 8       22                         Process_Virtual_Bytes Peak
# 9       92              Memory Free System Page Table Entries
# 10      37                               Process_Thread Count
# 11      19                    Process_IO_Write Operations_sec
# 12      40                          Process_IO Read Bytes_sec
# 13      99                   Memory Pool Paged Resident Bytes
# 14      16                     Process_IO Read_Operations_sec
# 15      36                     Process_IO Data Operations_sec
# 16      32                                Process_Working Set
# 17      82  Memory Long-Term Average Standby Cache Lifetim...
# 18      67                            Memory Cache Bytes Peak
# 19      81                 Memory System Cache Resident Bytes
# 20      65                            Memory Pool Paged Bytes
# 21      97                   Memory System Driver Total Bytes
# 22      31                        Process_Pool Nonpaged Bytes
# 23      91                 Memory pct_ Committed Bytes In Use
# 24      77                                 Memory Cache Bytes
# 25      87                Memory System Driver Resident Bytes
# 26      88         Memory Standby Cache Normal Priority Bytes
# 27      21                             Process_pct_ User_Time
# 28      96                             Memory Committed Bytes
# 29       3                      Processor_pct_ Interrupt_Time
# 30      23                       Process_Page_File Bytes Peak
# 31      18                           Process_Working_Set_Peak
# 32      70                                Memory Commit Limit
# 33      46      Network_I(Intel R _82574L_GNC) Bytes Sent sec
# 34      20                            Process_Page_File Bytes
# 35      57  Network_I(Intel R _82574L_GNC) TCP Active RSC ...
# 36      58    Network_I(Intel R _82574L_GNC) Packets Sent sec
# 37      45  Network_I(Intel R _82574L_GNC) Bytes Received sec
# 38      49     Network_I(Intel R _82574L_GNC) Bytes Total sec
# 39      26                         Process_IO_Write_Bytes_sec
# 40      38                       Process_pct_ Privileged_Time
# 41      59  Network_I(Intel R _82574L_GNC) Packets Receive...
# 42      25                              Process_Private_Bytes
# 43       5                           Processor_pct_ User_Time
# 44      17                       Process_Working_Set_ Private
# 45      11                     Processor_pct_ Privileged_Time
# 46      83                 Memory Standby Cache Reserve Bytes
# 47      56         Network_I(Intel R _82574L_GNC) Packets sec
# 48      35                    Process_IO Other Operations_sec
# 49      52  Network_I(Intel R _82574L_GNC) Packets Sent Un...
# 50      54  Network_I(Intel R _82574L_GNC) Packets Receive...
# 51       1                           Processor_pct_ Idle_Time
# 52      74                      Memory Demand Zero Faults sec
# 53      66                 Memory Free & Zero Page List Bytes
# 54       6                             Processor_pct_ C1_Time
# 55      29                        Process_pct_ Processor_Time
# 56       7                      Processor_pct_ Processor_Time
# 57      79                             Memory Page Faults sec
# 58      33                            Process_Page Faults_sec
# 59      93                            Memory Available MBytes
# 60      75                            Memory Available KBytes
# 61      39                          Process_IO Data Bytes_sec
# 62     119           LogicalDisk(_Total) Disk Write Bytes sec
# 63     118            LogicalDisk(_Total) pct_ Disk Read Time
# 64      94                    Memory Modified Page List Bytes
# 65     122           LogicalDisk(_Total) pct_ Disk Write Time
# 66      13                          Processor_DPCs_Queued_sec
# 67      69                             Memory Available Bytes
# 68       8                        Processor_C1_ransitions_sec
# 69      24                         Process_IO_Other_Bytes_sec
# 70     114                 LogicalDisk(_Total) pct_ Disk Time
# 71     120             LogicalDisk(_Total) Disk Transfers sec
# 72      14                           Processor_Interrupts_sec
# 73     102                 LogicalDisk(_Total) pct_ Idle Time
# 74     123         LogicalDisk(_Total) Avg  Disk sec Transfer
# 75     112                 LogicalDisk(_Total) Disk Bytes sec
# 76     111            LogicalDisk(_Total) Avg  Disk sec Write
# 77     117         LogicalDisk(_Total) Avg  Disk Queue Length
# 78      80                       Memory Transition Faults sec
# 79     107                LogicalDisk(_Total) Disk Writes sec
# 80      95                            Memory Cache Faults sec
# 81     100                            Memory Write Copies sec
# 82     101          LogicalDisk(_Total) Avg  Disk Bytes Write
# 83     116   LogicalDisk(_Total) Avg  Disk Write Queue Length
# 84     121       LogicalDisk(_Total) Avg  Disk Bytes Transfer
# 85       9                            Processor_pct_ DPC_Time
# 86      73                              Memory Page Reads sec
# 87     109                   LogicalDisk(_Total) Split IO Sec
# 88      76                                   Memory Pages sec
# 89     106             LogicalDisk(_Total) Avg  Disk sec Read
# 90      98                             Memory Pages Input sec
# 91     103                 LogicalDisk(_Total) Disk Reads sec
# 92     113    LogicalDisk(_Total) Avg  Disk Read Queue Length
# 93     105            LogicalDisk(_Total) Disk Read Bytes sec
# 94       0                                 Processor_DPC_Rate
# 95     115           LogicalDisk(_Total) Avg  Disk Bytes Read
# 96      71             Memory Transition Pages RePurposed sec
# 97     108      LogicalDisk(_Total) Current Disk Queue Length
# 98      72                            Memory Pages Output sec
# 99      89                           Memory Pool Paged Allocs
# 100     84                             Memory Page Writes sec
# 101     68                  Memory System Code Resident Bytes
# 102     85                     Memory System Code Total Bytes
# 103     90                        Memory Pool Nonpaged Allocs
# 104     30                        Process_Creating Process ID
# 105     34                                 Process_ID Process
# 106     10                        Processor_C2_ransitions_sec
# 107     27                               Process_Elapsed_Time
# 108     12                        Processor_C3_ransitions_sec
# 109     44  Network_I(Intel R _82574L_GNC) Packets Receive...
# 110      4                             Processor_pct_ C2_Time
# 111      2                             Processor_pct_ C3_Time
# 112     41                              Process_Priority Base
# 113     51  Network_I(Intel R _82574L_GNC) TCP RSC Excepti...
# 114     47  Network_I(Intel R _82574L_GNC) Packets Outboun...
# 115     48  Network_I(Intel R _82574L_GNC) Packets Receive...
# 116     50  Network_I(Intel R _82574L_GNC) Packets Outboun...
# 117     53  Network_I(Intel R _82574L_GNC) Output Queue Le...
# 118     55   Network_I(Intel R _82574L_GNC) Current Bandwidth
# 119     60  Network_I(Intel R _82574L_GNC) Packets Sent No...
# 120     61  Network_I(Intel R _82574L_GNC) Packets Receive...
# 121     63  Network_I(Intel R _82574L_GNC) Offloaded Conne...
# 122     64  Network_I(Intel R _82574L_GNC) Packets Receive...
# 123     62  Network_I(Intel R _82574L_GNC) TCP RSC Coalesc...
#
#      Feature Importance
# 0              0.070798
# 1              0.050383
# 2              0.044526
# 3              0.044251
# 4              0.040058
# 5              0.038633
# 6              0.036753
# 7              0.034563
# 8              0.033997
# 9              0.033804
# 10             0.030798
# 11             0.030573
# 12             0.030363
# 13             0.024252
# 14             0.022392
# 15             0.021170
# 16             0.020961
# 17             0.019823
# 18             0.019301
# 19             0.018594
# 20             0.018520
# 21             0.016604
# 22             0.016087
# 23             0.014324
# 24             0.013423
# 25             0.012977
# 26             0.011639
# 27             0.011394
# 28             0.011272
# 29             0.009833
# 30             0.008324
# 31             0.008000
# 32             0.007483
# 33             0.007305
# 34             0.007192
# 35             0.007135
# 36             0.006767
# 37             0.006629
# 38             0.006614
# 39             0.006258
# 40             0.006164
# 41             0.006163
# 42             0.005832
# 43             0.005583
# 44             0.005514
# 45             0.005377
# 46             0.005227
# 47             0.004906
# 48             0.004873
# 49             0.004304
# 50             0.004285
# 51             0.003935
# 52             0.003884
# 53             0.003821
# 54             0.003790
# 55             0.003235
# 56             0.003225
# 57             0.002949
# 58             0.002871
# 59             0.002792
# 60             0.002683
# 61             0.002481
# 62             0.002129
# 63             0.002033
# 64             0.001807
# 65             0.001754
# 66             0.001731
# 67             0.001636
# 68             0.001409
# 69             0.001213
# 70             0.001181
# 71             0.001100
# 72             0.001042
# 73             0.001041
# 74             0.001012
# 75             0.000992
# 76             0.000984
# 77             0.000930
# 78             0.000878
# 79             0.000876
# 80             0.000866
# 81             0.000847
# 82             0.000802
# 83             0.000768
# 84             0.000747
# 85             0.000631
# 86             0.000478
# 87             0.000461
# 88             0.000436
# 89             0.000403
# 90             0.000390
# 91             0.000389
# 92             0.000303
# 93             0.000295
# 94             0.000276
# 95             0.000275
# 96             0.000076
# 97             0.000061
# 98             0.000032
# 99             0.000024
# 100            0.000015
# 101            0.000008
# 102            0.000004
# 103            0.000000
# 104            0.000000
# 105            0.000000
# 106            0.000000
# 107            0.000000
# 108            0.000000
# 109            0.000000
# 110            0.000000
# 111            0.000000
# 112            0.000000
# 113            0.000000
# 114            0.000000
# 115            0.000000
# 116            0.000000
# 117            0.000000
# 118            0.000000
# 119            0.000000
# 120            0.000000
# 121            0.000000
# 122            0.000000
# 123            0.000000

# %%
pd.set_option('display.max_rows', 124)
fi_df.head(124)
# Out:
#      index                                            Feature  \
# 0       15                           Process_Pool_Paged Bytes
# 1       28                              Process_Virtual_Bytes
# 2      104                LogicalDisk(_Total) pct_ Free Space
# 3      110                 LogicalDisk(_Total) Free Megabytes
# 4       86                    Memory Standby Cache Core Bytes
# 5       42                               Process_Handle Count
# 6       78                         Memory Pool Nonpaged Bytes
# 7       43              Network_I(Intel R _82574L_GNC)TCP_APS
# 8       22                         Process_Virtual_Bytes Peak
# 9       92              Memory Free System Page Table Entries
# 10      37                               Process_Thread Count
# 11      19                    Process_IO_Write Operations_sec
# 12      40                          Process_IO Read Bytes_sec
# 13      99                   Memory Pool Paged Resident Bytes
# 14      16                     Process_IO Read_Operations_sec
# 15      36                     Process_IO Data Operations_sec
# 16      32                                Process_Working Set
# 17      82  Memory Long-Term Average Standby Cache Lifetim...
# 18      67                            Memory Cache Bytes Peak
# 19      81                 Memory System Cache Resident Bytes
# 20      65                            Memory Pool Paged Bytes
# 21      97                   Memory System Driver Total Bytes
# 22      31                        Process_Pool Nonpaged Bytes
# 23      91                 Memory pct_ Committed Bytes In Use
# 24      77                                 Memory Cache Bytes
# 25      87                Memory System Driver Resident Bytes
# 26      88         Memory Standby Cache Normal Priority Bytes
# 27      21                             Process_pct_ User_Time
# 28      96                             Memory Committed Bytes
# 29       3                      Processor_pct_ Interrupt_Time
# 30      23                       Process_Page_File Bytes Peak
# 31      18                           Process_Working_Set_Peak
# 32      70                                Memory Commit Limit
# 33      46      Network_I(Intel R _82574L_GNC) Bytes Sent sec
# 34      20                            Process_Page_File Bytes
# 35      57  Network_I(Intel R _82574L_GNC) TCP Active RSC ...
# 36      58    Network_I(Intel R _82574L_GNC) Packets Sent sec
# 37      45  Network_I(Intel R _82574L_GNC) Bytes Received sec
# 38      49     Network_I(Intel R _82574L_GNC) Bytes Total sec
# 39      26                         Process_IO_Write_Bytes_sec
# 40      38                       Process_pct_ Privileged_Time
# 41      59  Network_I(Intel R _82574L_GNC) Packets Receive...
# 42      25                              Process_Private_Bytes
# 43       5                           Processor_pct_ User_Time
# 44      17                       Process_Working_Set_ Private
# 45      11                     Processor_pct_ Privileged_Time
# 46      83                 Memory Standby Cache Reserve Bytes
# 47      56         Network_I(Intel R _82574L_GNC) Packets sec
# 48      35                    Process_IO Other Operations_sec
# 49      52  Network_I(Intel R _82574L_GNC) Packets Sent Un...
# 50      54  Network_I(Intel R _82574L_GNC) Packets Receive...
# 51       1                           Processor_pct_ Idle_Time
# 52      74                      Memory Demand Zero Faults sec
# 53      66                 Memory Free & Zero Page List Bytes
# 54       6                             Processor_pct_ C1_Time
# 55      29                        Process_pct_ Processor_Time
# 56       7                      Processor_pct_ Processor_Time
# 57      79                             Memory Page Faults sec
# 58      33                            Process_Page Faults_sec
# 59      93                            Memory Available MBytes
# 60      75                            Memory Available KBytes
# 61      39                          Process_IO Data Bytes_sec
# 62     119           LogicalDisk(_Total) Disk Write Bytes sec
# 63     118            LogicalDisk(_Total) pct_ Disk Read Time
# 64      94                    Memory Modified Page List Bytes
# 65     122           LogicalDisk(_Total) pct_ Disk Write Time
# 66      13                          Processor_DPCs_Queued_sec
# 67      69                             Memory Available Bytes
# 68       8                        Processor_C1_ransitions_sec
# 69      24                         Process_IO_Other_Bytes_sec
# 70     114                 LogicalDisk(_Total) pct_ Disk Time
# 71     120             LogicalDisk(_Total) Disk Transfers sec
# 72      14                           Processor_Interrupts_sec
# 73     102                 LogicalDisk(_Total) pct_ Idle Time
# 74     123         LogicalDisk(_Total) Avg  Disk sec Transfer
# 75     112                 LogicalDisk(_Total) Disk Bytes sec
# 76     111            LogicalDisk(_Total) Avg  Disk sec Write
# 77     117         LogicalDisk(_Total) Avg  Disk Queue Length
# 78      80                       Memory Transition Faults sec
# 79     107                LogicalDisk(_Total) Disk Writes sec
# 80      95                            Memory Cache Faults sec
# 81     100                            Memory Write Copies sec
# 82     101          LogicalDisk(_Total) Avg  Disk Bytes Write
# 83     116   LogicalDisk(_Total) Avg  Disk Write Queue Length
# 84     121       LogicalDisk(_Total) Avg  Disk Bytes Transfer
# 85       9                            Processor_pct_ DPC_Time
# 86      73                              Memory Page Reads sec
# 87     109                   LogicalDisk(_Total) Split IO Sec
# 88      76                                   Memory Pages sec
# 89     106             LogicalDisk(_Total) Avg  Disk sec Read
# 90      98                             Memory Pages Input sec
# 91     103                 LogicalDisk(_Total) Disk Reads sec
# 92     113    LogicalDisk(_Total) Avg  Disk Read Queue Length
# 93     105            LogicalDisk(_Total) Disk Read Bytes sec
# 94       0                                 Processor_DPC_Rate
# 95     115           LogicalDisk(_Total) Avg  Disk Bytes Read
# 96      71             Memory Transition Pages RePurposed sec
# 97     108      LogicalDisk(_Total) Current Disk Queue Length
# 98      72                            Memory Pages Output sec
# 99      89                           Memory Pool Paged Allocs
# 100     84                             Memory Page Writes sec
# 101     68                  Memory System Code Resident Bytes
# 102     85                     Memory System Code Total Bytes
# 103     90                        Memory Pool Nonpaged Allocs
# 104     30                        Process_Creating Process ID
# 105     34                                 Process_ID Process
# 106     10                        Processor_C2_ransitions_sec
# 107     27                               Process_Elapsed_Time
# 108     12                        Processor_C3_ransitions_sec
# 109     44  Network_I(Intel R _82574L_GNC) Packets Receive...
# 110      4                             Processor_pct_ C2_Time
# 111      2                             Processor_pct_ C3_Time
# 112     41                              Process_Priority Base
# 113     51  Network_I(Intel R _82574L_GNC) TCP RSC Excepti...
# 114     47  Network_I(Intel R _82574L_GNC) Packets Outboun...
# 115     48  Network_I(Intel R _82574L_GNC) Packets Receive...
# 116     50  Network_I(Intel R _82574L_GNC) Packets Outboun...
# 117     53  Network_I(Intel R _82574L_GNC) Output Queue Le...
# 118     55   Network_I(Intel R _82574L_GNC) Current Bandwidth
# 119     60  Network_I(Intel R _82574L_GNC) Packets Sent No...
# 120     61  Network_I(Intel R _82574L_GNC) Packets Receive...
# 121     63  Network_I(Intel R _82574L_GNC) Offloaded Conne...
# 122     64  Network_I(Intel R _82574L_GNC) Packets Receive...
# 123     62  Network_I(Intel R _82574L_GNC) TCP RSC Coalesc...
#
#      Feature Importance
# 0              0.070798
# 1              0.050383
# 2              0.044526
# 3              0.044251
# 4              0.040058
# 5              0.038633
# 6              0.036753
# 7              0.034563
# 8              0.033997
# 9              0.033804
# 10             0.030798
# 11             0.030573
# 12             0.030363
# 13             0.024252
# 14             0.022392
# 15             0.021170
# 16             0.020961
# 17             0.019823
# 18             0.019301
# 19             0.018594
# 20             0.018520
# 21             0.016604
# 22             0.016087
# 23             0.014324
# 24             0.013423
# 25             0.012977
# 26             0.011639
# 27             0.011394
# 28             0.011272
# 29             0.009833
# 30             0.008324
# 31             0.008000
# 32             0.007483
# 33             0.007305
# 34             0.007192
# 35             0.007135
# 36             0.006767
# 37             0.006629
# 38             0.006614
# 39             0.006258
# 40             0.006164
# 41             0.006163
# 42             0.005832
# 43             0.005583
# 44             0.005514
# 45             0.005377
# 46             0.005227
# 47             0.004906
# 48             0.004873
# 49             0.004304
# 50             0.004285
# 51             0.003935
# 52             0.003884
# 53             0.003821
# 54             0.003790
# 55             0.003235
# 56             0.003225
# 57             0.002949
# 58             0.002871
# 59             0.002792
# 60             0.002683
# 61             0.002481
# 62             0.002129
# 63             0.002033
# 64             0.001807
# 65             0.001754
# 66             0.001731
# 67             0.001636
# 68             0.001409
# 69             0.001213
# 70             0.001181
# 71             0.001100
# 72             0.001042
# 73             0.001041
# 74             0.001012
# 75             0.000992
# 76             0.000984
# 77             0.000930
# 78             0.000878
# 79             0.000876
# 80             0.000866
# 81             0.000847
# 82             0.000802
# 83             0.000768
# 84             0.000747
# 85             0.000631
# 86             0.000478
# 87             0.000461
# 88             0.000436
# 89             0.000403
# 90             0.000390
# 91             0.000389
# 92             0.000303
# 93             0.000295
# 94             0.000276
# 95             0.000275
# 96             0.000076
# 97             0.000061
# 98             0.000032
# 99             0.000024
# 100            0.000015
# 101            0.000008
# 102            0.000004
# 103            0.000000
# 104            0.000000
# 105            0.000000
# 106            0.000000
# 107            0.000000
# 108            0.000000
# 109            0.000000
# 110            0.000000
# 111            0.000000
# 112            0.000000
# 113            0.000000
# 114            0.000000
# 115            0.000000
# 116            0.000000
# 117            0.000000
# 118            0.000000
# 119            0.000000
# 120            0.000000
# 121            0.000000
# 122            0.000000
# 123            0.000000

# %% [markdown]
# **Feature importance based on random forest**

# %%
df = df.loc[:, ['LogicalDisk(_Total) Free Megabytes' , 'LogicalDisk(_Total) pct_ Free Space' , 'Memory Pool Paged Resident Bytes', 'Memory System Driver Total Bytes' ,'Memory Committed Bytes' , 'Memory Free System Page Table Entries', 'Memory Standby Cache Core Bytes','Memory System Driver Resident Bytes','Memory Standby Cache Normal Priority Bytes', 'Memory Long-Term Average Standby Cache Lifetime (s)', 'Memory Free System Page Table Entries','Memory System Cache Resident Bytes' , 'Memory Pool Nonpaged Bytes', 'Memory Cache Bytes', 'Memory Pool Paged Bytes','Memory Cache Bytes Peak', 'Network_I(Intel R _82574L_GNC) Bytes Sent sec' ,'Network_I(Intel R _82574L_GNC)TCP_APS','Process_IO Read Bytes_sec','Process_Handle Count','Process_IO Data Operations_sec','Process_Thread Count','Process_Pool Nonpaged Bytes','Process_Working Set','Process_Virtual_Bytes','Process_pct_ User_Time','Process_Virtual_Bytes Peak','Process_Working_Set_Peak','Process_IO_Write Operations_sec' ,'Process_Pool_Paged Bytes','Process_IO Read_Operations_sec', 'label' ]]

# %%
df = df.astype(float)

# %%
plt.figure(figsize=(30, 30))
sns.heatmap(df.corr(), annot=True, linewidth = 3, cmap='mako')
# Out:
# <AxesSubplot:>

# %%
df.drop('Memory Free System Page Table Entries', inplace = True, axis = 1)

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(df.corr(), annot=True, linewidth = 3, cmap='mako')
# Out:
# <AxesSubplot:>

# %%
# df = df.loc[:, ['Memory Pool Paged Resident Bytes','Memory System Driver Total Bytes', 'Memory Standby Cache Core Bytes', 'Memory Long-Term Average Standby Cache Lifetime (s)','Memory Pool Nonpaged Bytes','Memory Pool Paged Bytes','Network_I(Intel R _82574L_GNC) Bytes Sent sec' ,'Network_I(Intel R _82574L_GNC)TCP_APS', 'Process_Handle Count','Process_Thread Count','Process_Working Set','Process_Virtual_Bytes','Process_Virtual_Bytes Peak','Process_Working_Set_Peak', 'Process_Pool_Paged Bytes', 'label']] 
# #---corelation heatmap---- 
# import seaborn as sns
# plt.figure(figsize=(20, 15)) 
# sns.heatmap(df.corr(), annot=True, linewidth = 3, cmap='mako')

# %%
# import matplotlib.pyplot as plt
# columns = df.columns
# for col in columns:
#     print("col: ", col)
#     plt.scatter(df.index, df[col])
#     plt.show()

# %%
df.drop(['Memory System Driver Total Bytes',
'Memory System Driver Resident Bytes',
'Memory System Cache Resident Bytes',
'Memory Pool Nonpaged Bytes',
'Memory Pool Paged Bytes',
'Memory Cache Bytes Peak',
'Network_I(Intel R _82574L_GNC)TCP_APS',
'Process_Handle Count',
'Process_Thread Count',
'Process_Working Set',
'Process_Virtual_Bytes',
'Process_Virtual_Bytes Peak',
'Process_Working_Set_Peak',
'Process_Pool_Paged Bytes'], inplace = True, axis = 1)

# %%
# import matplotlib.pyplot as plt
# columns = df.columns
# for col in columns:
#     print("col: ", col)
#     plt.scatter(df.index, df[col])
#     plt.show()

# %%
df.head()
# Out:
#    LogicalDisk(_Total) Free Megabytes  LogicalDisk(_Total) pct_ Free Space  \
# 0                            167984.0                            82.156219
# 1                            167984.0                            82.156219
# 2                            167984.0                            82.156219
# 3                            167984.0                            82.156219
# 4                            167984.0                            82.156219
#
#    Memory Pool Paged Resident Bytes  Memory Committed Bytes  \
# 0                        83619840.0            3.460387e+09
# 1                        83984384.0            3.459990e+09
# 2                        79081472.0            3.522941e+09
# 3                        52133888.0            3.688444e+09
# 4                        29245440.0            3.688333e+09
#
#    Memory Standby Cache Core Bytes  \
# 0                      157052928.0
# 1                      157036544.0
# 2                      113893376.0
# 3                        2453504.0
# 4                        2338816.0
#
#    Memory Standby Cache Normal Priority Bytes  \
# 0                                  95240192.0
# 1                                  94769152.0
# 2                                  23834624.0
# 3                                  63152128.0
# 4                                  52461568.0
#
#    Memory Long-Term Average Standby Cache Lifetime (s)  Memory Cache Bytes  \
# 0                                               48.0            18944000.0
# 1                                               48.0            16445440.0
# 2                                               46.0            14024704.0
# 3                                               29.0             5312512.0
# 4                                               31.0             2392064.0
#
#    Network_I(Intel R _82574L_GNC) Bytes Sent sec  Process_IO Read Bytes_sec  \
# 0                                     221.720966               8.755815e+04
# 1                                     210.620362               7.339650e+04
# 2                                     209.808634               3.775767e+06
# 3                                     262.663637               4.887542e+06
# 4                                     210.484576               4.646488e+06
#
#    Process_IO Data Operations_sec  Process_Pool Nonpaged Bytes  \
# 0                      293.825345                    2447032.0
# 1                      239.723175                    2451920.0
# 2                      694.779399                    2408264.0
# 3                      677.628039                    2318640.0
# 4                      753.786644                    2248992.0
#
#    Process_pct_ User_Time  Process_IO_Write Operations_sec  \
# 0              122.055019                       282.909543
# 1              118.289188                       230.722305
# 2               92.055880                       373.889746
# 3               95.612437                       296.474808
# 4               83.590059                       306.531906
#
#    Process_IO Read_Operations_sec  label
# 0                       10.915802    0.0
# 1                        9.000870    0.0
# 2                      320.889654    0.0
# 3                      381.153231    0.0
# 4                      447.254738    0.0

# %%
#Mention column name along with range
temp = df[(df['LogicalDisk(_Total) Free Megabytes'] >= 165000) & (df['LogicalDisk(_Total) Free Megabytes']<= 175000)] 
#Mention Column name along with column index
df['LogicalDisk(_Total) Free Megabytes'] = temp.iloc[:,0]

#Mention column name along with range
temp = df[(df['LogicalDisk(_Total) pct_ Free Space'] >= 80) & (df['LogicalDisk(_Total) pct_ Free Space']<= 84)] 
#Mention Column name along with column index
df['LogicalDisk(_Total) pct_ Free Space'] = temp.iloc[:,1]

#Mention column name along with range
temp = df[(df['Memory Pool Paged Resident Bytes'] >= .75*10**8) & (df['Memory Pool Paged Resident Bytes']<= 2*10**8)] 
#Mention Column name along with column index
df['Memory Pool Paged Resident Bytes'] = temp.iloc[:,2]

#Mention column name along with range
temp = df[(df['Memory Committed Bytes'] >= 0.2*10**10) & (df['Memory Committed Bytes']<= 0.6*10**10)] 
#Mention Column name along with column index
df['Memory Committed Bytes'] = temp.iloc[:,3]


#Mention column name along with range
temp = df[(df['Memory Standby Cache Core Bytes'] >= 1*10**8) & (df['Memory Standby Cache Core Bytes']<= 2.25*10**8)] 
#Mention Column name along with column index
df['Memory Standby Cache Core Bytes'] = temp.iloc[:,4]


#Mention column name along with range
temp = df[(df['Memory Standby Cache Normal Priority Bytes'] >= 0) & (df['Memory Standby Cache Normal Priority Bytes']<= 0.5*10**9)] 
#Mention Column name along with column index
df['Memory Standby Cache Normal Priority Bytes'] = temp.iloc[:,5]


df['Memory Long-Term Average Standby Cache Lifetime (s)'] = df['Memory Long-Term Average Standby Cache Lifetime (s)']

#Mention column name along with range
temp = df[(df['Memory Cache Bytes'] >= 0) & (df['Memory Cache Bytes']<= 2*10**8)] 
#Mention Column name along with column index
df['Memory Cache Bytes'] = temp.iloc[:,7]

#Mention column name along with range
temp = df[(df['Network_I(Intel R _82574L_GNC) Bytes Sent sec'] >= 0) & (df['Network_I(Intel R _82574L_GNC) Bytes Sent sec']<= 100000)] 
#Mention Column name along with column index
df['Network_I(Intel R _82574L_GNC) Bytes Sent sec'] = temp.iloc[:,8]


#Mention column name along with range
temp = df[(df['Process_IO Read Bytes_sec'] >= 0) & (df['Process_IO Read Bytes_sec']<= 2*10**7)] 
#Mention Column name along with column index
df['Process_IO Read Bytes_sec'] = temp.iloc[:,9]

#Mention column name along with range
temp = df[(df['Process_IO Data Operations_sec'] >= 0) & (df['Process_IO Data Operations_sec']<= 10000)] 
#Mention Column name along with column index
df['Process_IO Data Operations_sec'] = temp.iloc[:,10]


#Mention column name along with range
temp = df[(df['Process_Pool Nonpaged Bytes'] >= 0) & (df['Process_Pool Nonpaged Bytes']<= 4*10**6)] 
#Mention Column name along with column index
df['Process_Pool Nonpaged Bytes'] = temp.iloc[:,11]


#Mention column name along with range
temp = df[(df['Process_pct_ User_Time'] >= 0) & (df['Process_pct_ User_Time']<= 100)] 
#Mention Column name along with column index
df['Process_pct_ User_Time'] = temp.iloc[:,12]


#Mention column name along with range
temp = df[(df['Process_IO_Write Operations_sec'] >= 0) & (df['Process_IO_Write Operations_sec']<= 500)] 
#Mention Column name along with column index
df['Process_IO_Write Operations_sec'] = temp.iloc[:,13]


#Mention column name along with range
temp = df[(df['Process_IO Read_Operations_sec'] >= 0) & (df['Process_IO Read_Operations_sec']<= 8000)] 
#Mention Column name along with column index
df['Process_IO Read_Operations_sec'] = temp.iloc[:,14]

# %%
# import matplotlib.pyplot as plt
# columns = df.columns
# for col in columns:
#     print("col: ", col)
#     plt.scatter(df.index, df[col])
#     plt.show()

# %%
df.isnull().sum().sum()
# Out:
# 25933

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

x = df.drop('label', axis=1)
y = df['label']

model = RandomForestClassifier()
model.fit(x, y)

(pd.Series(model.feature_importances_, index=x.columns)
   # .nlargest(4)
   .plot(kind='barh',figsize = (5, 5) ))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(df.corr(), annot=True, linewidth = 3, cmap='mako')
# Out:
# <AxesSubplot:>

# %%
df.drop('LogicalDisk(_Total) pct_ Free Space', axis = 1, inplace = True)

# %%
df_scaled = df

# %%
x_scaled = df_scaled.drop('label', axis=1)
y_scaled = df_scaled['label']

# %%
df_scaled.head(10)
# Out:
#     LogicalDisk(_Total) Free Megabytes  Memory Pool Paged Resident Bytes  \
# 2                             167984.0                        79081472.0
# 58                            167789.0                        75649024.0
# 59                            167789.0                        78942208.0
# 60                            167789.0                        81887232.0
# 61                            167789.0                        84430848.0
# 62                            167789.0                        90017792.0
# 63                            167789.0                        91901952.0
# 64                            167789.0                       102043648.0
# 65                            167789.0                       100126720.0
# 66                            167789.0                        94240768.0
#
#     Memory Committed Bytes  Memory Standby Cache Core Bytes  \
# 2             3.522941e+09                      113893376.0
# 58            3.156525e+09                      163835904.0
# 59            3.149775e+09                      163803136.0
# 60            3.157340e+09                      163770368.0
# 61            3.168883e+09                      163241984.0
# 62            3.168973e+09                      163225600.0
# 63            3.183190e+09                      163225600.0
# 64            3.179278e+09                      162885632.0
# 65            3.183841e+09                      162885632.0
# 66            3.189535e+09                      162893824.0
#
#     Memory Standby Cache Normal Priority Bytes  \
# 2                                   23834624.0
# 58                                  87298048.0
# 59                                  88109056.0
# 60                                  79532032.0
# 61                                  73543680.0
# 62                                  71020544.0
# 63                                  71024640.0
# 64                                  69582848.0
# 65                                  65732608.0
# 66                                  66048000.0
#
#     Memory Long-Term Average Standby Cache Lifetime (s)  Memory Cache Bytes  \
# 2                                                46.0            14024704.0
# 58                                               68.0            10297344.0
# 59                                               69.0            10911744.0
# 60                                               68.0            11735040.0
# 61                                               66.0            12251136.0
# 62                                               63.0            11264000.0
# 63                                               61.0             9953280.0
# 64                                               58.0            10588160.0
# 65                                               56.0            11550720.0
# 66                                               55.0            10989568.0
#
#     Network_I(Intel R _82574L_GNC) Bytes Sent sec  Process_IO Read Bytes_sec  \
# 2                                      209.808634               3.775767e+06
# 58                                     227.154148               3.518996e+04
# 59                                     242.996323               3.449038e+04
# 60                                     237.597537               3.392755e+04
# 61                                    1539.629711               2.957457e+04
# 62                                     248.786569               3.374313e+04
# 63                                     263.791382               3.596828e+04
# 64                                     243.371296               3.341959e+04
# 65                                     225.246700               3.565557e+04
# 66                                     254.899690               3.604226e+04
#
#     Process_IO Data Operations_sec  Process_Pool Nonpaged Bytes  \
# 2                       694.779399                    2408264.0
# 58                       97.351778                    2034952.0
# 59                       96.698537                    2035696.0
# 60                       92.399042                    2035248.0
# 61                       84.070572                    1948400.0
# 62                       91.442084                    1948960.0
# 63                      100.743946                    1950864.0
# 64                       95.746074                    1950832.0
# 65                       99.444022                    1950624.0
# 66                       99.299879                    1950480.0
#
#     Process_pct_ User_Time  Process_IO_Write Operations_sec  \
# 2                92.055880                       373.889746
# 58               34.741750                        47.073390
# 59               38.593336                        47.899275
# 60               37.030571                        46.199521
# 61               39.158494                        40.038360
# 62               42.409767                        45.670964
# 63               36.974123                        49.822823
# 64               40.373880                        47.672731
# 65               38.533394                        49.222794
# 66               38.125308                        49.699940
#
#     Process_IO Read_Operations_sec  label
# 2                       320.889654    0.0
# 58                       50.278387    0.0
# 59                       48.799262    0.0
# 60                       46.199521    0.0
# 61                       44.032212    0.0
# 62                       45.771120    0.0
# 63                       50.921122    0.0
# 64                       48.073342    0.0
# 65                       50.221228    0.0
# 66                       49.599940    0.0

# %%
x = df.drop('label', axis=1)
y = df['label']

# %%
x.head()
# Out:
#     LogicalDisk(_Total) Free Megabytes  Memory Pool Paged Resident Bytes  \
# 2                             167984.0                        79081472.0
# 58                            167789.0                        75649024.0
# 59                            167789.0                        78942208.0
# 60                            167789.0                        81887232.0
# 61                            167789.0                        84430848.0
#
#     Memory Committed Bytes  Memory Standby Cache Core Bytes  \
# 2             3.522941e+09                      113893376.0
# 58            3.156525e+09                      163835904.0
# 59            3.149775e+09                      163803136.0
# 60            3.157340e+09                      163770368.0
# 61            3.168883e+09                      163241984.0
#
#     Memory Standby Cache Normal Priority Bytes  \
# 2                                   23834624.0
# 58                                  87298048.0
# 59                                  88109056.0
# 60                                  79532032.0
# 61                                  73543680.0
#
#     Memory Long-Term Average Standby Cache Lifetime (s)  Memory Cache Bytes  \
# 2                                                46.0            14024704.0
# 58                                               68.0            10297344.0
# 59                                               69.0            10911744.0
# 60                                               68.0            11735040.0
# 61                                               66.0            12251136.0
#
#     Network_I(Intel R _82574L_GNC) Bytes Sent sec  Process_IO Read Bytes_sec  \
# 2                                      209.808634               3.775767e+06
# 58                                     227.154148               3.518996e+04
# 59                                     242.996323               3.449038e+04
# 60                                     237.597537               3.392755e+04
# 61                                    1539.629711               2.957457e+04
#
#     Process_IO Data Operations_sec  Process_Pool Nonpaged Bytes  \
# 2                       694.779399                    2408264.0
# 58                       97.351778                    2034952.0
# 59                       96.698537                    2035696.0
# 60                       92.399042                    2035248.0
# 61                       84.070572                    1948400.0
#
#     Process_pct_ User_Time  Process_IO_Write Operations_sec  \
# 2                92.055880                       373.889746
# 58               34.741750                        47.073390
# 59               38.593336                        47.899275
# 60               37.030571                        46.199521
# 61               39.158494                        40.038360
#
#     Process_IO Read_Operations_sec
# 2                       320.889654
# 58                       50.278387
# 59                       48.799262
# 60                       46.199521
# 61                       44.032212

# %% [markdown]
# # Without Oversampling

# %%
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=15, shuffle = True, random_state=3)

# %%
df.shape
# Out:
# (14456, 15)

# %%
# --------------------------Random Forest -----------------------------------
for train_index, test_index in skf.split(x, y):
    x_train, x_test, y_train, y_test = x.iloc[train_index], x.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
    
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_jobs=-1, bootstrap= False, criterion= 'gini', max_depth= 10, max_features= 2, min_samples_leaf= 2, n_estimators= 200)
rfc.fit(x_train, y_train) #Training the model
y_pred_rfc = rfc.predict(x_test)
# print(y_pred_rfc)# printing predictions

#Accuracy Score

from sklearn.model_selection import cross_val_score
scores = cross_val_score(rfc, x, y, cv=8)
print("Cross Validation Score Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

from sklearn.metrics import accuracy_score
rfcAccuracy = round(accuracy_score(y_test, y_pred_rfc)*100,2)
print("Accuracy of rfc: ",rfcAccuracy)

#F1 Score

from sklearn.metrics import f1_score
rfcF1 = round(f1_score(y_test, y_pred_rfc)*100,2)
print("f1_score of rfc: ",rfcF1)

#AUC Score

from sklearn.metrics import roc_auc_score
rfcAuc = round(roc_auc_score (y_test, y_pred_rfc)*100,2)
print('AUC Score of rfc:',rfcAuc)
# Out:
# Cross Validation Score Accuracy: 0.87 (+/- 0.23)
# Accuracy of rfc:  96.47
# f1_score of rfc:  96.96
# AUC Score of rfc: 96.1

# %%
from sklearn.model_selection import learning_curve
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

log_reg = rfc


train_sizes, train_scores, test_scores = learning_curve(estimator=log_reg,
                                                       X=x_train,
                                                       y=y_train,
                                                       train_sizes=np.linspace(0.1, 1.0, 10),
                                                       cv=15,
                                                       n_jobs=-1)

# Calculate the mean and standard deviation of the training scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Calculate the mean and standard deviation of the test scores
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Plot the learning curve
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training accuracy')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')

plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Validation accuracy')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')

plt.grid()
plt.suptitle('RandomForestClassifier Learning Curve')
plt.xlabel('Number of training samples')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.ylim([0, 1.0])
plt.show()

# %%
#ROC CURVE:
from sklearn.metrics import roc_curve, auc, confusion_matrix

rfc_fpr, rfc_tpr, threshold = roc_curve(y_test, y_pred_rfc)
auc_rfc = auc(rfc_fpr, rfc_tpr)

plt.figure(figsize=(5, 5), dpi=100)
plt.plot(rfc_fpr, rfc_tpr, marker='.', label='Windows 10 rfc (auc = %0.3f)' % auc_rfc)

plt.xlabel('False Positive Rate -->')
plt.ylabel('True Positive Rate -->')

plt.legend()

plt.show()

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
import matplotlib.pyplot as plt
def plot(y_true, y_pred):
    labels = unique_labels(y_test)
    column = [f'Predicted{label}' for label in labels]
    indices = [f'Actual{label}' for label in labels]
    table = pd.DataFrame(confusion_matrix(y_true, y_pred), columns = column, index=indices)
    return sns.heatmap(table, annot = True, fmt = 'd', cmap = 'mako', ).set(title = 'RandomForestClassifier Confusion Matrix')

plot(y_test, y_pred_rfc)
# Out:
# [Text(0.5, 1.0, 'RandomForestClassifier Confusion Matrix')]

# %%
# from interpret.blackbox import LimeTabular
# from interpret import show
# # dtc = DecisionTreeClassifier()
# # dtc.fit(x_train, y_train)
# # y_pred = dtc.predict(x_test)
# # print(f"F1 Score {f1_score(y_test, y_pred, average='macro')}")
# # print(f"Accuracy {accuracy_score(y_test, y_pred)}")
# # %% Apply lime
# # Initilize Lime for Tabular data
# lime = LimeTabular(predict_fn=rfc.predict_proba, 
#                    data=x_train, 
#                    random_state=1)
# # Get local explanations
# lime_local = lime.explain_local(x_test[-200:], 
#                                 y_test[-200:], 
#                                 name='LIME')
# show(lime_local)

# %%
# --------------------------Decision Tree -----------------------------------
for train_index, test_index in skf.split(x, y):
    x_train, x_test, y_train, y_test = x.iloc[train_index], x.iloc[test_index], y.iloc[train_index], y.iloc[test_index]

from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train, y_train) #Training the model
y_pred_dtc = dtc.predict(x_test)
# print(y_pred_dtc)# printing predictions


#Accuracy Score

from sklearn.model_selection import cross_val_score
scores = cross_val_score(rfc, x, y, cv=8)
print("Cross Validation Score Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

from sklearn.metrics import accuracy_score
dtcAccuracy = round(accuracy_score(y_test, y_pred_dtc)*100,2)
print("Accuracy of Decisiontree: ",dtcAccuracy)

#F1 Score

from sklearn.metrics import f1_score
dtcF1 = round(f1_score(y_test, y_pred_dtc)*100,2)
print("f1_score of Decisiontree: ",dtcF1)

#AUC Score

from sklearn.metrics import roc_auc_score
dtcAuc = round(roc_auc_score (y_test, y_pred_dtc)*100,2)
print('AUC Score of Decision Tree:',dtcAuc)
# Out:
# Cross Validation Score Accuracy: 0.87 (+/- 0.23)
# Accuracy of Decisiontree:  94.7
# f1_score of Decisiontree:  95.35
# AUC Score of Decision Tree: 94.61

# %%
#ROC CURVE:
from sklearn.metrics import roc_curve, auc, confusion_matrix

dtc_fpr, dtc_tpr, threshold = roc_curve(y_test, y_pred_dtc)
auc_dtc = auc(dtc_fpr, dtc_tpr)

plt.figure(figsize=(5, 5), dpi=100)
plt.plot(dtc_fpr, dtc_tpr, marker='.', label='Windows 10 dtc (auc = %0.3f)' % auc_dtc)

plt.xlabel('False Positive Rate -->')
plt.ylabel('True Positive Rate -->')

plt.legend()

plt.show()

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
import matplotlib.pyplot as plt
def plot(y_true, y_pred):
    labels = unique_labels(y_test)
    column = [f'Predicted{label}' for label in labels]
    indices = [f'Actual{label}' for label in labels]
    table = pd.DataFrame(confusion_matrix(y_true, y_pred), columns = column, index=indices)
    return sns.heatmap(table, annot = True, fmt = 'd', cmap = 'mako', ).set(title = 'Decision Tree Confusion Matrix')

plot(y_test, y_pred_dtc)
# Out:
# [Text(0.5, 1.0, 'Decision Tree Confusion Matrix')]

# %%
from sklearn.model_selection import learning_curve
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

log_reg = dtc


train_sizes, train_scores, test_scores = learning_curve(estimator=log_reg,
                                                       X=x_train,
                                                       y=y_train,
                                                       train_sizes=np.linspace(0.1, 1.0, 10),
                                                       cv=15,
                                                       n_jobs=-1)

# Calculate the mean and standard deviation of the training scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Calculate the mean and standard deviation of the test scores
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Plot the learning curve
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training accuracy')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')

plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Validation accuracy')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')

plt.grid()
plt.suptitle('Decision Learning Curve')
plt.xlabel('Number of training samples')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.ylim([0, 1.0])
plt.show()

# %%
# from interpret.blackbox import LimeTabular
# from interpret import show
# # dtc = DecisionTreeClassifier()
# # dtc.fit(x_train, y_train)
# # y_pred = dtc.predict(x_test)
# # print(f"F1 Score {f1_score(y_test, y_pred, average='macro')}")
# # print(f"Accuracy {accuracy_score(y_test, y_pred)}")
# # %% Apply lime
# # Initilize Lime for Tabular data
# lime = LimeTabular(predict_fn=dtc.predict_proba, 
#                    data=x_train, 
#                    random_state=1)
# # Get local explanations
# lime_local = lime.explain_local(x_test[-200:], 
#                                 y_test[-200:], 
#                                 name='LIME')
# show(lime_local)

# %%
# --------------------------KNN -----------------------------------
for train_index, test_index in skf.split(x, y):
    x_train, x_test, y_train, y_test = x.iloc[train_index], x.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
    
from sklearn.preprocessing import MinMaxScaler
scaler= MinMaxScaler()
#fit scaler to train set, it will learn parameters
scaler.fit(x_train)
#transform train and test sets
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

#converting from numpy
x_train= pd.DataFrame(x_train_scaled, columns=x_train.columns)
x_test= pd.DataFrame(x_test_scaled, columns=x_test.columns)

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=13, p=3)
knn.fit(x_train, y_train) #Training the model
y_pred_knn = knn.predict(x_test)
# print(y_pred_knn)# printing predictions

#Accuracy Score

from sklearn.metrics import accuracy_score
knnAccuracy = round(accuracy_score(y_test, y_pred_knn)*100,2)
print("Accuracy of KNN: ",knnAccuracy)

#F1 Score

from sklearn.metrics import f1_score
knnF1 = round(f1_score(y_test, y_pred_knn)*100,2)
print("f1_score of KNN: ",knnF1)

#AUC Score

from sklearn.metrics import roc_auc_score
knnAuc = round(roc_auc_score (y_test, y_pred_knn)*100,2)
print('AUC Score of KNN:',knnAuc)
# Out:
# Accuracy of KNN:  95.33
# f1_score of KNN:  95.96
# AUC Score of KNN: 95.01

# %%
#ROC CURVE:
from sklearn.metrics import roc_curve, auc, confusion_matrix

knn_fpr, knn_tpr, threshold = roc_curve(y_test, y_pred_knn)
auc_knn = auc(knn_fpr, knn_tpr)

plt.figure(figsize=(5, 5), dpi=100)
plt.plot(knn_fpr, knn_tpr, marker='.', label='Windows 10 knn (auc = %0.3f)' % auc_knn)

plt.xlabel('False Positive Rate -->')
plt.ylabel('True Positive Rate -->')

plt.legend()

plt.show()

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
import matplotlib.pyplot as plt
def plot(y_true, y_pred):
    labels = unique_labels(y_test)
    column = [f'Predicted{label}' for label in labels]
    indices = [f'Actual{label}' for label in labels]
    table = pd.DataFrame(confusion_matrix(y_true, y_pred), columns = column, index=indices)
    return sns.heatmap(table, annot = True, fmt = 'd', cmap = 'mako', ).set(title = 'K-Nearest Neighbour Confusion Matrix')

plot(y_test, y_pred_knn)
# Out:
# [Text(0.5, 1.0, 'K-Nearest Neighbour Confusion Matrix')]

# %%
from sklearn.model_selection import learning_curve
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

log_reg = knn

train_sizes, train_scores, test_scores = learning_curve(estimator=log_reg,
                                                       X=x_train,
                                                       y=y_train,
                                                       train_sizes=np.linspace(0.1, 1.0, 10),
                                                       cv=15,
                                                       n_jobs=-1)

# Calculate the mean and standard deviation of the training scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Calculate the mean and standard deviation of the test scores
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Plot the learning curve
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training accuracy')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')

plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Validation accuracy')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')

plt.grid()
plt.suptitle('K-Nearest Neighbour Learning Curve')
plt.xlabel('Number of training samples')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.ylim([0, 1.0])
plt.show()

# %%
# from interpret.blackbox import LimeTabular
# from interpret import show
# # dtc = DecisionTreeClassifier()
# # dtc.fit(x_train, y_train)
# # y_pred = dtc.predict(x_test)
# # print(f"F1 Score {f1_score(y_test, y_pred, average='macro')}")
# # print(f"Accuracy {accuracy_score(y_test, y_pred)}")
# # %% Apply lime
# # Initilize Lime for Tabular data
# lime = LimeTabular(predict_fn=knn.predict_proba, 
#                    data=x_train, 
#                    random_state=1)
# # Get local explanations
# lime_local = lime.explain_local(x_test[50:100], 
#                                 y_test[50:100], 
#                                 name='LIME')
# show(lime_local)

# %%
#--------------------Logistic Regression ------------------------
for train_index, test_index in skf.split(x, y):
    x_train, x_test, y_train, y_test = x.iloc[train_index], x.iloc[test_index], y.iloc[train_index], y.iloc[test_index]

from sklearn.preprocessing import MinMaxScaler
scaler= MinMaxScaler()
#fit scaler to train set, it will learn parameters
scaler.fit(x_train)
#transform train and test sets
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

#converting from numpy
x_train= pd.DataFrame(x_train_scaled, columns=x_train.columns)
x_test= pd.DataFrame(x_test_scaled, columns=x_test.columns)

lr = LogisticRegression(class_weight="balanced")


lr.fit(x_train, y_train) #Training the model
y_pred_lr = lr.predict(x_test)
# print(y_pred_lr)# printing predictions


#Accuracy Score

from sklearn.model_selection import cross_val_score
scores = cross_val_score(rfc, x, y, cv=15)
print("Cross Validation Score Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))


from sklearn.metrics import accuracy_score
lrAccuracy = round(accuracy_score(y_test, y_pred_lr)*100,2)
print("Accuracy of LR: ",lrAccuracy)

#F1 Score

from sklearn.metrics import f1_score
lrF1 = round(f1_score(y_test, y_pred_lr)*100,2)
print("f1_score of LR: ",lrF1)

#AUC Score

from sklearn.metrics import roc_auc_score
lrAuc = round(roc_auc_score (y_test, y_pred_lr)*100,2)
print('AUC Score of LR:',lrAuc)
# Out:
# Cross Validation Score Accuracy: 0.87 (+/- 0.26)
# Accuracy of LR:  85.15
# f1_score of LR:  87.11
# AUC Score of LR: 84.69

# %%
#ROC CURVE:
from sklearn.metrics import roc_curve, auc, confusion_matrix

lr_fpr, lr_tpr, threshold = roc_curve(y_test, y_pred_lr)
auc_lr = auc(lr_fpr, lr_tpr)

plt.figure(figsize=(5, 5), dpi=100)
plt.plot(lr_fpr, lr_tpr, marker='.', label='Windows 10 lr (auc = %0.3f)' % auc_lr)

plt.xlabel('False Positive Rate -->')
plt.ylabel('True Positive Rate -->')

plt.legend()

plt.show()

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
import matplotlib.pyplot as plt
def plot(y_true, y_pred):
    labels = unique_labels(y_test)
    column = [f'Predicted{label}' for label in labels]
    indices = [f'Actual{label}' for label in labels]
    table = pd.DataFrame(confusion_matrix(y_true, y_pred), columns = column, index=indices)
    return sns.heatmap(table, annot = True, fmt = 'd', cmap = 'mako', ).set(title = 'Logistic Regression Confusion Matrix')

plot(y_test, y_pred_lr)
# Out:
# [Text(0.5, 1.0, 'Logistic Regression Confusion Matrix')]

# %%
from sklearn.model_selection import learning_curve
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

log_reg = LogisticRegression()


train_sizes, train_scores, test_scores = learning_curve(estimator=log_reg,
                                                       X=x_train,
                                                       y=y_train,
                                                       train_sizes=np.linspace(0.1, 1.0, 10),
                                                       cv=15,
                                                       n_jobs=-1)

# Calculate the mean and standard deviation of the training scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Calculate the mean and standard deviation of the test scores
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Plot the learning curve
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training accuracy')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')

plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Validation accuracy')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')

plt.grid()
plt.suptitle('LogisticRegression Learning Curve')
plt.xlabel('Number of training samples')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.ylim([0, 1.0])
plt.show()

# %%
# from interpret.blackbox import LimeTabular
# from interpret import show
# # dtc = DecisionTreeClassifier()
# # dtc.fit(x_train, y_train)
# # y_pred = dtc.predict(x_test)
# # print(f"F1 Score {f1_score(y_test, y_pred, average='macro')}")
# # print(f"Accuracy {accuracy_score(y_test, y_pred)}")
# # %% Apply lime
# # Initilize Lime for Tabular data
# lime = LimeTabular(predict_fn=knn.predict_proba, 
#                    data=x_train, 
#                    random_state=1)
# # Get local explanations
# lime_local = lime.explain_local(x_test[50:100], 
#                                 y_test[50:100], 
#                                 name='LIME')
# show(lime_local)

# %%
# from sklearn.datasets import make_blobs
# from sklearn.model_selection import RepeatedStratifiedKFold
# from sklearn.model_selection import GridSearchCV
# from sklearn.linear_model import LogisticRegression

# X, y = make_blobs(n_samples=1000, centers=2, n_features=100, cluster_std=20)
# # define models and parameters
# model = LogisticRegression()
# solvers = ['newton-cg', 'lbfgs', 'liblinear']
# penalty = ['l2']
# c_values = [100, 10, 1.0, 0.1, 0.01]

# # define grid search
# grid = dict(solver=solvers,penalty=penalty,C=c_values)
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
# grid_result = grid_search.fit(X, y)
# # summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, stdev, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, stdev, param))

# %%
#Plotting a bar graph to compare the accuracy scores of the different scoring metrics
dtc_scores = [dtcAccuracy, dtcF1, dtcAuc]
rfc_scores = [rfcAccuracy, rfcF1, rfcAuc]
KNN_scores = [knnAccuracy, knnF1, knnAuc]
LR_scores = [lrAccuracy, lrF1, lrAuc]

x_labels = ['Accuracy', 'F1 Score', 'AUC Score']

def autolabel(rectangle_group):
    for rect in rectangle_group:
        height = rect.get_height()

        ax.annotate(str(height), xy = (rect.get_x(), height+.19))

width = 0.17

x_dtc = [x-width for x in range (len(dtc_scores))]
x_rfc = [x for x in range (len(rfc_scores))]
x_KNN = [x+width for x in range (len(KNN_scores))]
x_LR = [x+(2*width) for x in range (len(LR_scores))]


fig,ax = plt.subplots(figsize = (10, 6))
rect1 = ax.bar(x_dtc ,dtc_scores, width, label='Decision Tree', color = 'pink', edgecolor='black')
rect2 = ax.bar(x_rfc, rfc_scores, width, label='Random Forest', color='cyan', edgecolor='black')
rect3 = ax.bar(x_KNN, KNN_scores, width, label='KNN', color='lightgreen', edgecolor='black')
rect4 = ax.bar(x_LR, LR_scores, width, label='Logistic Regression', color='silver', edgecolor='black')

plt.xticks([x for x in range(len(x_labels))], x_labels)
ax.set_title('Windows10')
ax.set_xlabel('Models')
ax.set_ylabel('Score %')
plt.ylim([70, 105])
ax.legend()

autolabel(rect1)
autolabel(rect2)
autolabel(rect3)
autolabel(rect4)
plt.show()

# %%
#ROC CURVE:
from sklearn.metrics import roc_curve, auc, confusion_matrix

rfc_fpr, rfc_tpr, threshold = roc_curve(y_test, y_pred_rfc)
auc_rfc = auc(rfc_fpr, rfc_tpr)

dtc_fpr, dtc_tpr, threshold = roc_curve(y_test, y_pred_dtc)
dtc_rfc = auc(dtc_fpr, dtc_tpr)

lr_fpr, lr_tpr, threshold = roc_curve(y_test, y_pred_dtc)
lr_rfc = auc(lr_fpr, lr_tpr)

knn_fpr, knn_tpr, threshold = roc_curve(y_test, y_pred_dtc)
knn_rfc = auc(knn_fpr, knn_tpr)

plt.figure(figsize=(5, 5), dpi=100)
plt.plot(rfc_fpr, rfc_tpr, marker='.', label='Windows 10 RFC (auc = %0.3f)' % auc_rfc)
plt.xlabel('False Positive Rate -->')
plt.ylabel('True Positive Rate -->')
plt.legend()

plt.plot(dtc_fpr, dtc_tpr, marker='.', label='Windows 10 DTC (auc = %0.3f)' % auc_dtc)
plt.xlabel('False Positive Rate -->')
plt.ylabel('True Positive Rate -->')
plt.legend()

plt.plot(lr_fpr, dtc_tpr, marker='.', label='Windows 10 LR (auc = %0.3f)' % auc_lr )
plt.xlabel('False Positive Rate -->')
plt.ylabel('True Positive Rate -->')
plt.legend()

plt.plot(knn_fpr, knn_tpr, marker='.', label='Windows 10 KNN (auc = %0.3f)' % auc_knn )

plt.xlabel('False Positive Rate -->')
plt.ylabel('True Positive Rate -->')

plt.legend()

plt.show()
